# %% [markdown]
# [Link](https://datafai.com/auto-arima-using-pyramid-arima-python-package/)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize']=18,9

# Load specific forecasting tools
from statsmodels.tsa.arima_model import ARIMA,ARIMAResults
from statsmodels.tsa.seasonal import seasonal_decompose

# for determining (p,q) orders
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf 
# for determining ARIMA orders
from pmdarima import auto_arima 

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
! pip show pandas
# Out:
# Name: pandas
# Version: 1.1.0
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: None
# Author-email: None
# License: BSD
# Location: c:\users\jaspr\anaconda3\envs\tsa_course\lib\site-packages
# Requires: pytz, numpy, python-dateutil
# Required-by: statsmodels, seaborn, pmdarima

# %%
# Load datasets
df1 = pd.read_csv('./Data/airline_passengers.csv',index_col='Month',parse_dates=True)
df1.index.freq = 'MS'
df1.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
df1.plot();

# %%
data_decompose = seasonal_decompose(df1['Thousands of Passengers'])
data_decompose.plot();

# %% [markdown]
# ## Stationarity Test

# %%
from pmdarima.arima import ADFTest
adf_test_autoarima = ADFTest(alpha=0.05); 
_, stationarity_bool = adf_test_autoarima.is_stationary(df1["Thousands of Passengers"])
print(f'Is Stationary? {stationarity_bool}')
# Out:
# Is Stationary? False

# %%
len(df1["Thousands of Passengers"])
# Out:
# 144

# %%
train, test = df1["Thousands of Passengers"][:132], df1["Thousands of Passengers"][132:]
print(len(test)); print(len(train));
# Out:
# 12
# 132

# %%
train.plot()
test.plot();

# %%
arima_model = auto_arima(train, seasonal=True, m=12, trace=True)
arima_model.summary()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-a1a73a9da825> in <module>
# ----> 1 arima_model = auto_arima(train, seasonal=True, m=12, trace=True)
#       2 arima_model.summary()
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\pmdarima\arima\auto.py in auto_arima(y, exogenous, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, transparams, solver, maxiter, disp, callback, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, **fit_args)
#     639
#     640         # fit a baseline p, d, q model and then a null model
# --> 641         stepwise_wrapper.fit_increment_k_cache_set(True)  # p, d, q, P, D, Q
#     642         stepwise_wrapper.fit_increment_k_cache_set(
#     643             True, p=0, q=0, P=0, Q=0)  # null model
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\pmdarima\arima\auto.py in fit_increment_k_cache_set(self, expr, p, q, P, Q)
#     794                              scoring=self.scoring,
#     795                              scoring_args=self.scoring_args,
# --> 796                              with_intercept=self.with_intercept)
#     797
#     798             # use the orders as a key to be hashed for
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\pmdarima\arima\auto.py in _fit_arima(x, xreg, order, seasonal_order, start_params, trend, method, transparams, solver, maxiter, disp, callback, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept)
#     862                     scoring_args=scoring_args,
#     863                     with_intercept=with_intercept)\
# --> 864             .fit(x, exogenous=xreg, **fit_params)
#     865
#     866     # for non-stationarity errors or singular matrices, return None
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\pmdarima\arima\arima.py in fit(self, y, exogenous, **fit_args)
#     366                 fit, self.arima_res_ = _fit_wrapper()
#     367         else:
# --> 368             fit, self.arima_res_ = _fit_wrapper()
#     369
#     370         # Set df_model attribute for SARIMAXResults object
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\pmdarima\arima\arima.py in _fit_wrapper()
#     358                                     solver=self.solver, maxiter=self.maxiter,
#     359                                     disp=self.disp, callback=self.callback,
# --> 360                                     **fit_args)
#     361
#     362         # sometimes too many warnings...
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     657                                                full_output=full_output,
#     658                                                disp=disp, callback=callback,
# --> 659                                                skip_hessian=True, **kwargs)
#     660
#     661         # Just return the fitted parameters if requested
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\statsmodels\base\model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     524                                                        callback=callback,
#     525                                                        retall=retall,
# --> 526                                                        full_output=full_output)
#     527
#     528         # NOTE: this is for fit_regularized and should be generalized
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\statsmodels\base\optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     216                             disp=disp, maxiter=maxiter, callback=callback,
#     217                             retall=retall, full_output=full_output,
# --> 218                             hess=hessian)
#     219
#     220         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\statsmodels\base\optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     438                                      callback=callback, args=fargs,
#     439                                      bounds=bounds, disp=disp,
# --> 440                                      **extra_kwargs)
#     441
#     442     if full_output:
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\scipy\optimize\lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     196
#     197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 198                            **opts)
#     199     d = {'grad': res['jac'],
#     200          'task': res['message'],
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\scipy\optimize\lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_and_grad(self, x)
#     199             self._update_x_impl(x)
#     200         self._update_fun()
# --> 201         self._update_grad()
#     202         return self.f, self.g
#     203
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_grad(self)
#     169     def _update_grad(self):
#     170         if not self.g_updated:
# --> 171             self._update_grad_impl()
#     172             self.g_updated = True
#     173
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_grad()
#      90                 self.ngev += 1
#      91                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
# ---> 92                                            **finite_diff_options)
#      93
#      94         self._update_grad_impl = update_grad
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\scipy\optimize\_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     425         if sparsity is None:
#     426             return _dense_difference(fun_wrapped, x0, f0, h,
# --> 427                                      use_one_sided, method)
#     428         else:
#     429             if not issparse(sparsity) and len(sparsity) == 2:
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\scipy\optimize\_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     495             x = x0 + h_vecs[i]
#     496             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 497             df = fun(x) - f0
#     498         elif method == '3-point' and use_one_sided[i]:
#     499             x1 = x0 + h_vecs[i]
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\scipy\optimize\_numdiff.py in fun_wrapped(x)
#     375
#     376     def fun_wrapped(x):
# --> 377         f = np.atleast_1d(fun(x, *args, **kwargs))
#     378         if f.ndim > 1:
#     379             raise RuntimeError("`fun` return value has "
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\statsmodels\base\model.py in f(params, *args)
#     498
#     499         def f(params, *args):
# --> 500             return -self.loglike(params, *args) / nobs
#     501
#     502         if method == 'newton':
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in loglike(self, params, *args, **kwargs)
#     882                                     includes_fixed=includes_fixed)
#     883         self.update(params, transformed=True, includes_fixed=True,
# --> 884                     complex_step=complex_step)
#     885
#     886         if complex_step:
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in update(self, params, transformed, includes_fixed, complex_step)
#    1650             data = np.dot(self._trend_data, params_trend).astype(params.dtype)
#    1651             if not self.hamilton_representation:
# -> 1652                 self.ssm['state_intercept', self._k_states_diff, :] = data
#    1653             else:
#    1654                 # The way the trend enters in the Hamilton representation means
#
# ~\Anaconda3\envs\tsa_course\lib\site-packages\statsmodels\tsa\statespace\representation.py in __setitem__(self, key, value)
#     444
#     445             # Set the new value
# --> 446             matrix[slice_] = value
#     447             setattr(self, name, matrix)
#     448         # Otherwise we got a single non-string key, (e.g. mod[:]), which is
#
# KeyboardInterrupt:

# %% [markdown]
# ## Use the best model to make predictions about the Test data-

# %%
predictions = pd.DataFrame(arima_model.predict(n_periods=3),index=test.index)
predictions.columns = ['Predicted_Passengers']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-450bfcc07d9d> in <module>
# ----> 1 predictions = pd.DataFrame(arima_model.predict(n_periods=3),index=test.index)
#       2 predictions.columns = ['Predicted_Passengers']
#
# NameError: name 'arima_model' is not defined

# %%
plt.plot(test,label="Test")
plt.plot(predictions,label="Predicted_Pasengers")
plt.legend(loc="upper left")
plt.show();

# %% [markdown]
# ## Evaluation

# %%
from statsmodels.tools.eval_measures import rmse
from sklearn.metrics import r2_score, mean_squared_error

rmse_error = np.sqrt(mean_squared_error(test, predictions))
print(f'RMSE Error: {rmse_error}')
print("Test's mean:",test.mean())


r2_result = r2_score(test, predictions)
print(f"RSq: {r2_result}")
